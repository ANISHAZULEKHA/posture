# %%
import pandas as pd
import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.models import Sequential

# Load the dataset
posture_data = pd.read_csv("posture2.csv")

# Prepare features and labels
features = posture_data[["Ax1", "Ay1", "Az1", "Ax2", "Ay2", "Az2"]].values
numeric_labels = posture_data["label"].values

# Map numeric labels to descriptive labels
label_mapping = {
    1: 'Good',
    2: 'Good',
    3: 'Bad',
    4: 'Worse',
    5: 'Worse'
}

descriptive_labels = np.array([label_mapping[int(label)] for label in numeric_labels])

# Encode labels as integers
unique_labels = np.unique(descriptive_labels)
label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
int_labels = np.array([label_to_int[label] for label in descriptive_labels])

# Convert labels to categorical
num_classes = len(unique_labels)
labels = to_categorical(int_labels, num_classes=num_classes)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Define the model
model = Sequential()
model.add(Dense(units=32, activation="relu", input_dim=6))
model.add(Dense(units=16, activation="relu"))
model.add(Dense(units=num_classes, activation="softmax"))

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

# Evaluate the model
prediction = model.evaluate(x_test, y_test)

# Print the accuracy
print(f"Accuracy: {prediction[1]}")

# Save the model
model.save("posture_predictor.h5")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-3969cd1ca585> in <cell line: 24>()
#      22 }
#      23
# ---> 24 descriptive_labels = np.array([label_mapping[int(label)] for label in numeric_labels])
#      25
#      26 # Encode labels as integers
#
# <ipython-input-3-3969cd1ca585> in <listcomp>(.0)
#      22 }
#      23
# ---> 24 descriptive_labels = np.array([label_mapping[int(label)] for label in numeric_labels])
#      25
#      26 # Encode labels as integers
#
# KeyError: 0

# %%
import pandas as pd
import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.layers import Dense
from keras.models import Sequential

# Load the dataset
posture_data = pd.read_csv("posture2.csv")

# Prepare features and labels
features = posture_data[["Ax1", "Ay1", "Az1", "Ax2", "Ay2", "Az2"]].values
numeric_labels = posture_data["label"].values

# Map numeric labels to descriptive labels
label_mapping = {
    0: 'Good',   # Adding the 0 label to the mapping
    1: 'Good',
    2: 'Good',
    3: 'Bad',
    4: 'Worse',
    5: 'Worse'
}

# Convert numeric labels to descriptive labels
descriptive_labels = np.array([label_mapping[int(label)] for label in numeric_labels])

# Encode labels as integers
unique_labels = np.unique(descriptive_labels)
label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
int_labels = np.array([label_to_int[label] for label in descriptive_labels])

# Convert labels to categorical
num_classes = len(unique_labels)
labels = to_categorical(int_labels, num_classes=num_classes)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Define the model
model = Sequential()
model.add(Dense(units=32, activation="relu", input_dim=6))
model.add(Dense(units=16, activation="relu"))
model.add(Dense(units=num_classes, activation="softmax"))

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

# Evaluate the model
prediction = model.evaluate(x_test, y_test)

# Print the accuracy
print(f"Accuracy: {prediction[1]}")

# Save the model
model.save("posture_predictor.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8591 - loss: 0.4404 - val_accuracy: 0.9896 - val_loss: 0.0440
# Epoch 2/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9908 - loss: 0.0345 - val_accuracy: 0.9932 - val_loss: 0.0252
# Epoch 3/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9941 - loss: 0.0209 - val_accuracy: 0.9943 - val_loss: 0.0210
# Epoch 4/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9958 - loss: 0.0157 - val_accuracy: 0.9941 - val_loss: 0.0203
# Epoch 5/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9949 - loss: 0.0166 - val_accuracy: 0.9949 - val_loss: 0.0187
# Epoch 6/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9962 - loss: 0.0148 - val_accuracy: 0.9955 - val_loss: 0.0168
# Epoch 7/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9958 - loss: 0.0144 - val_accuracy: 0.9959 - val_loss: 0.0155
# Epoch 8/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9960 - loss: 0.0144 - val_accuracy: 0.9960 - val_loss: 0.0156
# Epoch 9/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9958 - loss: 0.0141 - val_accuracy: 0.9955 - val_loss: 0.0171
# Epoch 10/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9966 - loss: 0.0118 - val_accuracy: 0.9959 - val_loss: 0.0154
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0151
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Accuracy: 0.9959443807601929

# %%
import pandas as pd
import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Input
from keras.models import Sequential, load_model

# Load the dataset
posture_data = pd.read_csv("posture2.csv")

# Prepare features and labels
features = posture_data[["Ax1", "Ay1", "Az1", "Ax2", "Ay2", "Az2"]].values
numeric_labels = posture_data["label"].values

# Map numeric labels to descriptive labels
label_mapping = {
    0: 'Good',   # Assuming 0 should be included
    1: 'Good',
    2: 'Good',
    3: 'Bad',
    4: 'Worse',
    5: 'Worse'
}

# Convert numeric labels to descriptive labels
descriptive_labels = np.array([label_mapping[int(label)] for label in numeric_labels])

# Encode labels as integers
unique_labels = np.unique(descriptive_labels)
label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
int_labels = np.array([label_to_int[label] for label in descriptive_labels])

# Convert labels to categorical
num_classes = len(unique_labels)
labels = to_categorical(int_labels, num_classes=num_classes)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Define the model
model = Sequential()
model.add(Input(shape=(6,)))
model.add(Dense(units=32, activation="relu"))
model.add(Dense(units=16, activation="relu"))
model.add(Dense(units=num_classes, activation="softmax"))

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

# Evaluate the model
prediction = model.evaluate(x_test, y_test)
print(f"Accuracy: {prediction[1]}")

# Save the model using the recommended Keras format
model.save("posture_predictor.keras")

# Load the model (if needed later)
# model = load_model("posture_predictor.keras")

# Example of making a prediction with new data
new_data = np.array([[0.75, 0.60, -0.72, 0.80, 0.62, -0.74]])  # Replace with actual sensor readings
prediction = model.predict(new_data)

# Get the class with the highest probability
predicted_class = np.argmax(prediction)

# Map the predicted class to the corresponding label
int_to_label = {v: k for k, v in label_to_int.items()}  # Reverse the label mapping
predicted_label = int_to_label[predicted_class]

print(f"Predicted Class: {predicted_class}")
print(f"Predicted Label: {predicted_label}")
# Out:
# Epoch 1/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8400 - loss: 0.4192 - val_accuracy: 0.9862 - val_loss: 0.0455
# Epoch 2/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9900 - loss: 0.0356 - val_accuracy: 0.9889 - val_loss: 0.0324
# Epoch 3/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9933 - loss: 0.0230 - val_accuracy: 0.9941 - val_loss: 0.0207
# Epoch 4/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9948 - loss: 0.0195 - val_accuracy: 0.9948 - val_loss: 0.0180
# Epoch 5/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9946 - loss: 0.0171 - val_accuracy: 0.9951 - val_loss: 0.0163
# Epoch 6/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9958 - loss: 0.0161 - val_accuracy: 0.9957 - val_loss: 0.0174
# Epoch 7/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9955 - loss: 0.0138 - val_accuracy: 0.9963 - val_loss: 0.0153
# Epoch 8/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9968 - loss: 0.0111 - val_accuracy: 0.9963 - val_loss: 0.0148
# Epoch 9/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9957 - loss: 0.0140 - val_accuracy: 0.9954 - val_loss: 0.0159
# Epoch 10/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9962 - loss: 0.0119 - val_accuracy: 0.9963 - val_loss: 0.0146
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9967 - loss: 0.0140
# Accuracy: 0.9963064789772034
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Predicted Class: 0
# Predicted Label: Bad

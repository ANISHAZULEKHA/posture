# %% [markdown]
# <a href="https://colab.research.google.com/github/ANISHAZULEKHA/posture/blob/main/posturepred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.layers import Dense, Input
from keras.models import Sequential, load_model

# Load the dataset
posture_data = pd.read_csv("posture2.csv")

# Prepare features and labels
features = posture_data[["Ax1", "Ay1", "Az1", "Ax2", "Ay2", "Az2"]].values
numeric_labels = posture_data["label"].values

# Map numeric labels to descriptive labels
label_mapping = {
    0: 'Good',   # Assuming 0 should be included
    1: 'Good',
    2: 'Good',
    3: 'Bad',
    4: 'Worse',
    5: 'Worse'
}

# Convert numeric labels to descriptive labels
descriptive_labels = np.array([label_mapping[int(label)] for label in numeric_labels])

# Encode labels as integers
unique_labels = np.unique(descriptive_labels)
label_to_int = {label: idx for idx, label in enumerate(unique_labels)}
int_labels = np.array([label_to_int[label] for label in descriptive_labels])

# Convert labels to categorical
num_classes = len(unique_labels)
labels = to_categorical(int_labels, num_classes=num_classes)

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Define the model
model = Sequential()
model.add(Input(shape=(6,)))
model.add(Dense(units=32, activation="relu"))
model.add(Dense(units=16, activation="relu"))
model.add(Dense(units=num_classes, activation="softmax"))

# Compile the model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))

# Evaluate the model
prediction = model.evaluate(x_test, y_test)
print(f"Accuracy: {prediction[1]}")

# Save the model using the recommended Keras format
model.save("posture_predictor.keras")

# Load the model (if needed later)
# model = load_model("posture_predictor.keras")

# Generating 100 predictions for testing
# Assuming x_test has at least 100 samples

# Select the first 100 examples from the test set
test_samples = x_test[:100]

# Make predictions
predictions = model.predict(test_samples)

# Map the predictions to labels
predicted_classes = np.argmax(predictions, axis=1)
predicted_labels = [list(label_to_int.keys())[list(label_to_int.values()).index(cls)] for cls in predicted_classes]

# Display the results
for i, (data, prediction, label) in enumerate(zip(test_samples, predicted_classes, predicted_labels)):
    print(f"Sample {i + 1}:")
    print(f"Data: {data}")
    print(f"Predicted Class: {prediction}")
    print(f"Predicted Label: {label}\n")
# Out:
# Epoch 1/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8902 - loss: 0.4005 - val_accuracy: 0.9893 - val_loss: 0.0386
# Epoch 2/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9907 - loss: 0.0339 - val_accuracy: 0.9918 - val_loss: 0.0253
# Epoch 3/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9930 - loss: 0.0229 - val_accuracy: 0.9928 - val_loss: 0.0211
# Epoch 4/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9938 - loss: 0.0193 - val_accuracy: 0.9949 - val_loss: 0.0185
# Epoch 5/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9948 - loss: 0.0168 - val_accuracy: 0.9954 - val_loss: 0.0165
# Epoch 6/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9954 - loss: 0.0153 - val_accuracy: 0.9957 - val_loss: 0.0148
# Epoch 7/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9959 - loss: 0.0137 - val_accuracy: 0.9964 - val_loss: 0.0133
# Epoch 8/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9965 - loss: 0.0121 - val_accuracy: 0.9960 - val_loss: 0.0138
# Epoch 9/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9959 - loss: 0.0134 - val_accuracy: 0.9964 - val_loss: 0.0128
# Epoch 10/10
# 1726/1726 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9960 - loss: 0.0119 - val_accuracy: 0.9963 - val_loss: 0.0119
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - accuracy: 0.9964 - loss: 0.0114
# Accuracy: 0.9963064789772034
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Sample 1:
# Data: [ 0.01196 -0.37988  0.94995 -0.13867  0.44678  0.8252 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 2:
# Data: [-1.22289214  0.53570856 -0.17446928 -0.88221302  0.44158309 -0.01337963]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 3:
# Data: [-0.42261   0.062744  0.12012  -2.        1.9999    1.9999  ]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 4:
# Data: [-0.96442819  0.06836     0.09756271 -0.84913679  0.27061303 -0.39981755]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 5:
# Data: [-0.79795851 -0.00721733  0.58801439 -0.87134     0.17746772  0.31467772]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 6:
# Data: [-0.92358  0.18726 -0.16455 -0.10693  0.08691  0.94214]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 7:
# Data: [-0.67725   0.33984  -0.63306  -0.93677   0.002686 -0.16406 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 8:
# Data: [-1.0355681   0.12033393 -0.10896352 -0.78436685  0.52819855  0.23711391]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 9:
# Data: [-0.97299404 -0.14661454 -0.11929161 -0.91079674 -0.06701138 -0.21080344]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 10:
# Data: [-0.16626 -0.46973  0.88013  0.3352  -0.03735  0.96924]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 11:
# Data: [-0.62549   0.24023  -0.70996  -0.94336   0.034912 -0.146   ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 12:
# Data: [-0.92871 -0.22559  0.2019  -0.00806  0.23218  0.92432]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 13:
# Data: [-0.45215  -0.080078 -0.87451  -0.91821  -0.022705  0.20532 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 14:
# Data: [-0.79492  -0.014893  0.59522  -0.86865   0.17578   0.30273 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 15:
# Data: [-0.95776 -0.06128 -0.16431 -0.9812  -0.01294  0.18945]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 16:
# Data: [-0.16817037 -0.40714764  0.93087789  0.0055705   0.14999604  0.96179938]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 17:
# Data: [-0.949672    0.14738435 -0.04254623 -0.95280216 -0.08081    -0.09322668]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 18:
# Data: [-0.88745  0.3313   0.25049 -0.17065  0.17261  0.9314 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 19:
# Data: [-0.09668  -0.10889   0.078613 -1.0959    0.26148   0.060059]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 20:
# Data: [-0.88843  0.31299  0.23608 -0.16773  0.1731   0.94263]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 21:
# Data: [-0.92676751  0.09797666 -0.2394299  -0.92832294 -0.01609373 -0.25717199]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 22:
# Data: [0.30527132 0.29262925 0.94833903 0.1218163  0.45723176 0.85776247]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 23:
# Data: [-0.80294996 -0.00836896  0.5824668  -0.86886996  0.1739766   0.30754664]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 24:
# Data: [-0.79907  -0.008301  0.59741  -0.87134   0.17505   0.31641 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 25:
# Data: [-0.88385415  0.48580151 -0.35520027 -1.08307591  0.13399202  0.02198666]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 26:
# Data: [-0.93538303 -0.12278671 -0.24434594 -0.12731712  0.11053685  0.94855145]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 27:
# Data: [-0.48047  -0.086914 -0.86255  -0.92065  -0.019775  0.19727 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 28:
# Data: [-0.91089 -0.09399 -0.32056 -0.04297 -0.06592  0.95605]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 29:
# Data: [-0.83882216  0.22647146 -0.12300745 -1.03787677  0.68232589 -0.15593522]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 30:
# Data: [-0.51855  -0.10523  -0.81274  -0.91895  -0.025146  0.19995 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 31:
# Data: [-0.61133   0.10864  -0.75952  -0.94629  -0.001953 -0.10986 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 32:
# Data: [-2.         -0.25627334  0.63858393 -0.26213048  0.51442438  0.846416  ]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 33:
# Data: [-0.94971  0.20557  0.01123 -0.92627 -0.02466 -0.28394]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 34:
# Data: [-0.52832  -0.020508 -0.16065  -2.        0.73047   0.30273 ]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 35:
# Data: [-0.79541 -0.01123  0.58423 -0.86841  0.17407  0.30762]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 36:
# Data: [-0.94556 -0.11597 -0.12085 -1.01    -0.14282  0.09155]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 37:
# Data: [-0.74638238  0.41175135 -0.04545781 -0.64641192  0.43590138  0.08247631]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 38:
# Data: [-0.79581557 -0.00685524  0.59764398 -0.86781955  0.17503388  0.29973201]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 39:
# Data: [-2.      -0.1416  -0.1543  -0.80566 -0.55981  0.11231]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 40:
# Data: [-0.87964  0.32422  0.22803 -0.18726  0.16602  0.92407]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 41:
# Data: [-0.79395  -0.033203 -0.61499  -0.93091   0.016357 -0.10913 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 42:
# Data: [-1.9424    0.047607 -0.3208   -1.155     1.9999    0.27002 ]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 43:
# Data: [-0.46118  -0.19043  -0.86352  -0.92212  -0.020752  0.1919  ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 44:
# Data: [-0.66187  -0.055908 -0.7124   -0.93994   0.031494 -0.15332 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 45:
# Data: [ 0.50002209 -0.19871504 -0.00828041 -1.22593142  0.44076054  0.2499478 ]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 46:
# Data: [-0.51294  -0.10791  -0.85474  -0.92114  -0.026611  0.18628 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 47:
# Data: [-1.27176947  0.257664   -0.1247837  -0.81166463  0.19274369 -0.06140638]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 48:
# Data: [-0.93481  0.15112  0.24292 -0.18994  0.17114  0.93799]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 49:
# Data: [-0.94242023  0.09907385 -0.14132586 -0.09784373  0.06015142  0.96530589]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 50:
# Data: [-0.96435  0.01929  0.15674 -0.93799 -0.02759 -0.2478 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 51:
# Data: [-1.81724235  1.01932701 -0.48446904 -0.65872604  0.07482254 -0.40259898]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 52:
# Data: [-0.87695  0.33398  0.24683 -0.15308  0.15454  0.9375 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 53:
# Data: [-0.53247   0.44482  -0.67602  -0.9436    0.076172 -0.16553 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 54:
# Data: [-0.94385127 -0.19116049  0.18309515 -0.04516982  0.23754897  0.91235012]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 55:
# Data: [-0.80403327 -0.00545241  0.59350314 -0.86954635  0.17414955  0.31347314]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 56:
# Data: [-0.80176  -0.011963  0.60107  -0.86792   0.17334   0.30908 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 57:
# Data: [-0.47485  -0.1145   -0.8772   -0.91773  -0.030762  0.18677 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 58:
# Data: [-0.93433 -0.01831 -0.24902 -0.04468  0.04956  0.97266]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 59:
# Data: [-0.44702  -0.22119  -0.84522  -0.91675  -0.021484  0.20166 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 60:
# Data: [ 0.01787815 -0.39919029  0.960364   -0.07905426  0.25813359  0.91327957]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 61:
# Data: [-0.52808  -0.12915  -0.80737  -0.92041  -0.020508  0.20239 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 62:
# Data: [-0.8855   0.32617  0.2478  -0.15674  0.16089  0.9397 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 63:
# Data: [-2.        1.9999   -1.5881   -0.71851   0.020508 -0.40137 ]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 64:
# Data: [-0.8091613  -0.02552352  0.57173454 -0.89883489  0.01780072  0.27184677]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 65:
# Data: [-0.81494  -0.017822  0.59228  -0.90161   0.025146  0.26831 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 66:
# Data: [-0.93286 -0.13648  0.23267  0.07715  0.31689  0.89893]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 67:
# Data: [-0.95468674 -0.18468137  0.03697752 -0.01301987  0.26804002  0.9148    ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 68:
# Data: [-0.93262 -0.11279 -0.25537 -0.84644 -0.0415  -0.3252 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 69:
# Data: [-0.21524226 -0.01838014  0.03215694 -1.58583944  0.23234785 -0.29704709]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 70:
# Data: [-0.86206  0.40503  0.18164 -0.10938  0.17969  0.9397 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 71:
# Data: [0.18628 0.37793 0.91773 0.06372 0.31567 0.92847]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 72:
# Data: [-0.79126  -0.010498  0.58569  -0.88135   0.037109  0.30322 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 73:
# Data: [-0.81012744 -0.01968907  0.57878256 -0.90327672  0.01777777  0.2724444 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 74:
# Data: [-0.47681  -0.1001   -0.84766  -0.91992  -0.024658  0.19165 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 75:
# Data: [-0.94214 -0.19434  0.16455 -0.06494  0.20947  0.91065]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 76:
# Data: [-0.45727  -0.22339  -0.85205  -0.92212  -0.020752  0.20239 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 77:
# Data: [-0.66553   0.008057 -0.69458  -0.94727   0.067383 -0.13208 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 78:
# Data: [-0.85693  0.30762  0.35669 -0.13648  0.16626  0.93726]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 79:
# Data: [-0.95743703  0.07631771 -0.01326492 -0.97347858 -0.21147835 -0.09368526]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 80:
# Data: [-0.95654 -0.0249  -0.07349 -0.94751  0.01953 -0.20288]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 81:
# Data: [-0.00146 -0.39014  0.95605 -0.06006  0.28198  0.92285]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 82:
# Data: [-0.53052  -0.12817  -0.84497  -0.92798  -0.047119  0.18115 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 83:
# Data: [ 0.01666171 -0.34889115  0.98847409 -0.10539568  0.25601353  0.90649   ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 84:
# Data: [-0.79932  -0.013672  0.59473  -0.86816   0.17896   0.30542 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 85:
# Data: [0.38958446 0.12045226 0.95282256 0.12606626 0.45965446 0.85464844]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 86:
# Data: [-0.80856069 -0.02273917  0.5794868  -0.89934709  0.01695092  0.26241542]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 87:
# Data: [-0.90161  0.0813   0.44092 -0.15283  0.14404  0.94556]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 88:
# Data: [-0.51025   0.19336  -0.81397  -0.94263   0.027344 -0.1145  ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 89:
# Data: [-0.32803292 -0.13046514 -0.01962008 -1.34450416  0.40033333  0.11850225]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 90:
# Data: [-0.99341  0.36182 -0.25513 -0.62744  0.02832 -0.39355]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 91:
# Data: [-0.80318634 -0.02027361  0.5691333  -0.90016909  0.02338513  0.26779126]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 92:
# Data: [-0.89282  0.25098  0.18677 -0.81201  0.28247 -0.44898]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 93:
# Data: [-0.94482 -0.02368 -0.16919 -0.11401  0.02881  0.96728]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 94:
# Data: [ 0.53735 -0.26221  0.24219 -0.68481  0.68799 -0.21533]
# Predicted Class: 0
# Predicted Label: Bad
#
# Sample 95:
# Data: [-0.97607 -0.07788 -0.03882 -0.94946 -0.02881 -0.11108]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 96:
# Data: [-0.62769   0.39697  -0.63355  -0.93042   0.079346 -0.16675 ]
# Predicted Class: 2
# Predicted Label: Worse
#
# Sample 97:
# Data: [0.16382 0.36963 0.93848 0.09277 0.2981  0.92798]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 98:
# Data: [-0.05395 -0.4314   0.94556 -0.12451  0.31811  0.8894 ]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 99:
# Data: [-0.16577 -0.43115  0.93213  0.00195  0.45752  0.90674]
# Predicted Class: 1
# Predicted Label: Good
#
# Sample 100:
# Data: [-0.79492  -0.005615  0.58618  -0.87085   0.17602   0.31079 ]
# Predicted Class: 2
# Predicted Label: Worse
